# %%
import pandas as pd
import pylab as pl

# %%
data = pd.read_excel("costa_rica.xlsx")

# %%
pl.plot(data.cases)
pl.plot(data.deaths)

# %%
data.head()
# Out:
#    Unnamed: 0        date  cases  deaths  Unnamed: 4
# 0           0  2020-03-06      1     NaN    0.646089
# 1           1  2020-03-07      0     NaN         NaN
# 2           2  2020-03-08      4     NaN         NaN
# 3           3  2020-03-09      4     NaN         NaN
# 4           4  2020-03-10      0     NaN         NaN

# %%
data.shape
# Out:
# (722, 5)
